# %%
# !pip install pyautogui

import pyautogui 
import time
# -*- coding: utf-8 -*-

#Atividade compulsória
time.sleep(1)
pyautogui.click(298,1065)
time.sleep(1)
pyautogui.click(1125,364)
pyautogui.write('')
pyautogui.hotkey('enter')
pyautogui.write('67')
pyautogui.hotkey('Tab')
pyautogui.write('34')
pyautogui.hotkey('Tab')
pyautogui.write('94')
pyautogui.hotkey('Tab')
pyautogui.write('40')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('70')
pyautogui.hotkey('Tab')
pyautogui.write('89')
pyautogui.hotkey('Tab')
pyautogui.write('12')
pyautogui.hotkey('Tab')
pyautogui.write('17')
pyautogui.hotkey('Tab')
pyautogui.write('33')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('50')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('90')
pyautogui.hotkey('Tab')
pyautogui.write('23')
pyautogui.hotkey('Tab')
pyautogui.write('45')
pyautogui.hotkey('Tab')
pyautogui.click(1299,164)

# %%
# !pip install pyautogui

import pyautogui 
import time
# -*- coding: utf-8 -*-

#TESTE 1
time.sleep(1)
pyautogui.click(298,1065)
time.sleep(1)
pyautogui.click(1125,364)
pyautogui.write('99')
pyautogui.hotkey('enter')
pyautogui.write('71')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('34')
pyautogui.hotkey('Tab')
pyautogui.write('78')
pyautogui.hotkey('Tab')
pyautogui.write('23')
pyautogui.hotkey('Tab')
pyautogui.write('99')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('23')
pyautogui.hotkey('Tab')
pyautogui.write('45')
pyautogui.hotkey('Tab')
pyautogui.write('33')
pyautogui.hotkey('Tab')
pyautogui.write('12')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('50')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('90')
pyautogui.hotkey('Tab')
pyautogui.write('23')
pyautogui.hotkey('Tab')
pyautogui.write('45')
pyautogui.hotkey('Tab')
pyautogui.click(1299,164)

# %%
# !pip install pyautogui

import pyautogui 
import time
# -*- coding: utf-8 -*-

#Teste 2
time.sleep(1)
pyautogui.click(298,1065)
time.sleep(1)
pyautogui.click(1125,364)
pyautogui.write('100')
pyautogui.hotkey('enter')
pyautogui.hotkey('Tab')
pyautogui.write('72')
pyautogui.hotkey('Tab')
pyautogui.write('49')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('49')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('74')
pyautogui.hotkey('Tab')
pyautogui.write('77')
pyautogui.hotkey('Tab')
pyautogui.write('44')
pyautogui.hotkey('Tab')
pyautogui.write('56')
pyautogui.hotkey('Tab')
pyautogui.write('35')
pyautogui.hotkey('Tab')
pyautogui.write('22')
pyautogui.hotkey('Tab')
pyautogui.write('33')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('50')
pyautogui.hotkey('Tab')
pyautogui.click(1299,164)

# %%
# !pip install pyautogui

import pyautogui 
import time
# -*- coding: utf-8 -*-

#Teste 2
time.sleep(1)
pyautogui.click(298,1065)
time.sleep(1)
pyautogui.click(1125,364)
pyautogui.write('55')
pyautogui.hotkey('enter')
pyautogui.write('89')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('77')
pyautogui.hotkey('Tab')
pyautogui.write('90')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('77')
pyautogui.hotkey('Tab')
pyautogui.write('12')
pyautogui.hotkey('Tab')
pyautogui.write('23')
pyautogui.hotkey('Tab')
pyautogui.write('74')
pyautogui.hotkey('Tab')
pyautogui.write('77')
pyautogui.hotkey('Tab')
pyautogui.write('44')
pyautogui.hotkey('Tab')
pyautogui.write('56')
pyautogui.hotkey('Tab')
pyautogui.write('35')
pyautogui.hotkey('Tab')
pyautogui.write('22')
pyautogui.hotkey('Tab')
pyautogui.write('33')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('50')
pyautogui.hotkey('Tab')
pyautogui.click(1299,164)

# %%
# !pip install pyautogui

import pyautogui 
import time
# -*- coding: utf-8 -*-


time.sleep(1)
pyautogui.click(298,1065)
time.sleep(1)
pyautogui.click(1125,364)
pyautogui.hotkey('enter')
pyautogui.write('11')
pyautogui.hotkey('Tab')
pyautogui.write('71')
pyautogui.hotkey('Tab')
pyautogui.write('99')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('49')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('74')
pyautogui.hotkey('Tab')
pyautogui.write('77')
pyautogui.hotkey('Tab')
pyautogui.write('44')
pyautogui.hotkey('Tab')
pyautogui.write('56')
pyautogui.hotkey('Tab')
pyautogui.write('35')
pyautogui.hotkey('Tab')
pyautogui.write('22')
pyautogui.hotkey('Tab')
pyautogui.write('33')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('50')
pyautogui.hotkey('Tab')
pyautogui.click(1299,164)

# %%
# !pip install pyautogui

import pyautogui 
import time
# -*- coding: utf-8 -*-


time.sleep(1)
pyautogui.click(298,1065)
time.sleep(1)
pyautogui.click(1125,364)
pyautogui.write('37')
pyautogui.hotkey('enter')
pyautogui.hotkey('Tab')
pyautogui.write('49')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('99')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('49')
pyautogui.hotkey('Tab')
pyautogui.write('39')
pyautogui.hotkey('Tab')
pyautogui.write('74')
pyautogui.hotkey('Tab')
pyautogui.write('77')
pyautogui.hotkey('Tab')
pyautogui.write('44')
pyautogui.hotkey('Tab')
pyautogui.write('56')
pyautogui.hotkey('Tab')
pyautogui.write('35')
pyautogui.hotkey('Tab')
pyautogui.write('22')
pyautogui.hotkey('Tab')
pyautogui.write('33')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('50')
pyautogui.hotkey('Tab')
pyautogui.click(1299,164)

# %%
time.sleep(5)
print(pyautogui.position())
# Out:
# Point(x=1299, y=164)

# %%
# !pip install pyautogui

import pyautogui 
import time
# -*- coding: utf-8 -*-


time.sleep(1)
pyautogui.click(298,1065)
time.sleep(1)
pyautogui.click(1125,364)
pyautogui.write('50')
pyautogui.hotkey('enter')
pyautogui.write('')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('94')
pyautogui.hotkey('Tab')
pyautogui.write('90')
pyautogui.hotkey('Tab')
pyautogui.write('53')
pyautogui.hotkey('Tab')
pyautogui.write('57')
pyautogui.hotkey('Tab')
pyautogui.write('99')
pyautogui.hotkey('Tab')
pyautogui.write('23')
pyautogui.hotkey('Tab')
pyautogui.write('45')
pyautogui.hotkey('Tab')
pyautogui.write('33')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('50')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('90')
pyautogui.hotkey('Tab')
pyautogui.write('23')
pyautogui.hotkey('Tab')
pyautogui.write('45')
pyautogui.hotkey('Tab')
pyautogui.click(1299,164)

# %%
# !pip install pyautogui

import pyautogui 
import time
# -*- coding: utf-8 -*-


time.sleep(1)
pyautogui.click(298,1065)
time.sleep(1)
pyautogui.click(1125,364)
pyautogui.write('57')
pyautogui.hotkey('enter')
pyautogui.write('')
pyautogui.hotkey('Tab')
pyautogui.write('12')
pyautogui.hotkey('Tab')
pyautogui.write('74')
pyautogui.hotkey('Tab')
pyautogui.write('56')
pyautogui.hotkey('Tab')
pyautogui.write('89')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('99')
pyautogui.hotkey('Tab')
pyautogui.write('59')
pyautogui.hotkey('Tab')
pyautogui.write('45')
pyautogui.hotkey('Tab')
pyautogui.write('33')
pyautogui.hotkey('Tab')
pyautogui.write('34')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('50')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('90')
pyautogui.hotkey('Tab')
pyautogui.write('23')
pyautogui.hotkey('Tab')
pyautogui.write('45')
pyautogui.hotkey('Tab')
pyautogui.click(1299,164)

# %%
# !pip install pyautogui

import pyautogui 
import time
# -*- coding: utf-8 -*-


time.sleep(1)
pyautogui.click(298,1065)
time.sleep(1)
pyautogui.click(1125,364)
pyautogui.write('99')
pyautogui.hotkey('enter')
pyautogui.write('')
pyautogui.hotkey('Tab')
pyautogui.write('44')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('56')
pyautogui.hotkey('Tab')
pyautogui.write('97')
pyautogui.hotkey('Tab')
pyautogui.write('37')
pyautogui.hotkey('Tab')
pyautogui.write('99')
pyautogui.hotkey('Tab')
pyautogui.write('78')
pyautogui.hotkey('Tab')
pyautogui.write('45')
pyautogui.hotkey('Tab')
pyautogui.write('33')
pyautogui.hotkey('Tab')
pyautogui.write('34')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('50')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('90')
pyautogui.hotkey('Tab')
pyautogui.write('23')
pyautogui.hotkey('Tab')
pyautogui.write('45')
pyautogui.hotkey('Tab')
pyautogui.click(1299,164)

# %%
# !pip install pyautogui

import pyautogui 
import time
# -*- coding: utf-8 -*-


time.sleep(1)
pyautogui.click(298,1065)
time.sleep(1)
pyautogui.click(1125,364)
pyautogui.write('77')
pyautogui.hotkey('enter')
pyautogui.write('')
pyautogui.hotkey('Tab')
pyautogui.write('34')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('49')
pyautogui.hotkey('Tab')
pyautogui.write('89')
pyautogui.hotkey('Tab')
pyautogui.write('56')
pyautogui.hotkey('Tab')
pyautogui.write('45')
pyautogui.hotkey('Tab')
pyautogui.write('23')
pyautogui.hotkey('Tab')
pyautogui.write('34')
pyautogui.hotkey('Tab')
pyautogui.write('33')
pyautogui.hotkey('Tab')
pyautogui.write('45')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('34')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('90')
pyautogui.hotkey('Tab')
pyautogui.write('23')
pyautogui.hotkey('Tab')
pyautogui.write('45')
pyautogui.hotkey('Tab')
pyautogui.click(1299,164)

# %%
# !pip install pyautogui

import pyautogui 
import time
# -*- coding: utf-8 -*-


time.sleep(1)
pyautogui.click(298,1065)
time.sleep(1)
pyautogui.click(1125,364)
pyautogui.write('100')
pyautogui.hotkey('enter')
pyautogui.write('')
pyautogui.hotkey('Tab')
pyautogui.write('12')
pyautogui.hotkey('Tab')
pyautogui.write('34')
pyautogui.hotkey('Tab')
pyautogui.write('46')
pyautogui.hotkey('Tab')
pyautogui.write('89')
pyautogui.hotkey('Tab')
pyautogui.write('55')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('23')
pyautogui.hotkey('Tab')
pyautogui.write('77')
pyautogui.hotkey('Tab')
pyautogui.write('33')
pyautogui.hotkey('Tab')
pyautogui.write('45')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('34')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('90')
pyautogui.hotkey('Tab')
pyautogui.write('23')
pyautogui.hotkey('Tab')
pyautogui.write('45')
pyautogui.hotkey('Tab')
pyautogui.click(1299,164)

# %%
# !pip install pyautogui

import pyautogui 
import time
# -*- coding: utf-8 -*-


time.sleep(1)
pyautogui.click(298,1065)
time.sleep(1)
pyautogui.click(1125,364)
pyautogui.write('12')
pyautogui.hotkey('enter')
pyautogui.hotkey('Tab')
pyautogui.write('56')
pyautogui.hotkey('Tab')
pyautogui.write('90')
pyautogui.hotkey('Tab')
pyautogui.write('44')
pyautogui.hotkey('Tab')
pyautogui.write('12')
pyautogui.hotkey('Tab')
pyautogui.write('3')
pyautogui.hotkey('Tab')
pyautogui.write('67')
pyautogui.hotkey('Tab')
pyautogui.write('74')
pyautogui.hotkey('Tab')
pyautogui.write('45')
pyautogui.hotkey('Tab')
pyautogui.write('22')
pyautogui.hotkey('Tab')
pyautogui.write('56')
pyautogui.hotkey('Tab')
pyautogui.write('56')
pyautogui.hotkey('Tab')
pyautogui.write('22')
pyautogui.hotkey('Tab')
pyautogui.write('33')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('50')
pyautogui.hotkey('Tab')
pyautogui.click(1299,164)

# %%
# !pip install pyautogui

import pyautogui 
import time
# -*- coding: utf-8 -*-


time.sleep(1)
pyautogui.click(298,1065)
time.sleep(1)
pyautogui.click(1125,364)
pyautogui.write('88')
pyautogui.hotkey('enter')
pyautogui.hotkey('Tab')
pyautogui.write('45')
pyautogui.hotkey('Tab')
pyautogui.write('90')
pyautogui.hotkey('Tab')
pyautogui.write('99')
pyautogui.hotkey('Tab')
pyautogui.write('12')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('67')
pyautogui.hotkey('Tab')
pyautogui.write('74')
pyautogui.hotkey('Tab')
pyautogui.write('45')
pyautogui.hotkey('Tab')
pyautogui.write('49')
pyautogui.hotkey('Tab')
pyautogui.write('56')
pyautogui.hotkey('Tab')
pyautogui.write('56')
pyautogui.hotkey('Tab')
pyautogui.write('22')
pyautogui.hotkey('Tab')
pyautogui.write('33')
pyautogui.hotkey('Tab')
pyautogui.write('03')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('50')
pyautogui.hotkey('Tab')
pyautogui.click(1299,164)

# %%
# !pip install pyautogui

import pyautogui 
import time
# -*- coding: utf-8 -*-

#REFEITURA 1
time.sleep(1)
pyautogui.click(298,1065)
time.sleep(1)
pyautogui.click(1125,364)
pyautogui.write('77')
pyautogui.hotkey('enter')
pyautogui.hotkey('Tab')
pyautogui.write('45')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('23')
pyautogui.hotkey('Tab')
pyautogui.write('90')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('74')
pyautogui.hotkey('Tab')
pyautogui.write('45')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('56')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('56')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('22')
pyautogui.hotkey('Tab')
pyautogui.write('33')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('50')
pyautogui.hotkey('Tab')
pyautogui.click(1299,164)

# %%
# !pip install pyautogui

import pyautogui 
import time
# -*- coding: utf-8 -*-

#REFEITURA 2
time.sleep(1)
pyautogui.click(298,1065)
time.sleep(1)
pyautogui.click(1125,364)
pyautogui.write('')
pyautogui.hotkey('enter')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('77')
pyautogui.hotkey('Tab')
pyautogui.write('88')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('12')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('67')
pyautogui.hotkey('Tab')
pyautogui.write('34')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('22')
pyautogui.hotkey('Tab')
pyautogui.write('33')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('50')
pyautogui.hotkey('Tab')
pyautogui.click(1299,164)

# %%
# !pip install pyautogui

import pyautogui 
import time
# -*- coding: utf-8 -*-

#REFEITURA 3
time.sleep(1)
pyautogui.click(298,1065)
time.sleep(1)
pyautogui.click(1125,364)
pyautogui.write('93')
pyautogui.hotkey('enter')
pyautogui.hotkey('Tab')
pyautogui.write('77')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('23')
pyautogui.hotkey('Tab')
pyautogui.write('89')
pyautogui.hotkey('Tab')
pyautogui.write('34')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('67')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('33')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('34')
pyautogui.hotkey('Tab')
pyautogui.write('100')
pyautogui.hotkey('Tab')
pyautogui.write('12')
pyautogui.hotkey('Tab')
pyautogui.write('99')
pyautogui.hotkey('Tab')
pyautogui.hotkey('Tab')
pyautogui.write('80')
pyautogui.hotkey('Tab')
pyautogui.write('50')
pyautogui.hotkey('Tab')
pyautogui.click(1299,164)
